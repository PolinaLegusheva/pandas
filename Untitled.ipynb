# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('/home/pl/Documents/adult.csv')

# %% [markdown]
# ### Task 1

# %%
people_more50k = df[df['income']=='>50K']

# %%
country_counts = people_more50k['native-country'].value_counts()

# %%
max_country_counst = country_counts.idxmax()
max_country_counst
# Out:
# 'United-States'

# %% [markdown]
# ### Task 2

# %%
relationship_more50k = people_more50k['relationship']

# %%
relationship_value_counts = relationship_more50k.value_counts()
relationship_value_counts
# Out:
# Husband           8846
# Not-in-family     1276
# Wife              1093
# Unmarried          309
# Own-child          111
# Other-relative      52
# Name: relationship, dtype: int64

# %%
relationship_more50k.describe()
# Out:
# count       11687
# unique          6
# top       Husband
# freq         8846
# Name: relationship, dtype: object

# %%
plt.subplots(figsize = (16, 15))
sns.countplot(x = relationship_more50k, data = df)
_ = plt.xlabel('Relationship groups with income > 50k')

# %%
race_more50k = people_more50k['race']

# %%
race_value_counts = race_more50k.value_counts()
race_value_counts
# Out:
# White                 10607
# Black                   566
# Asian-Pac-Islander      409
# Amer-Indian-Eskimo       55
# Other                    50
# Name: race, dtype: int64

# %%
race_more50k.describe()
# Out:
# count     11687
# unique        5
# top       White
# freq      10607
# Name: race, dtype: object

# %%
plt.subplots(figsize = (16, 15))
sns.countplot(x = race_more50k, data = df)
_ = plt.xlabel('Race groups with income > 50k')

# %%
gender_more50k = people_more50k['gender']

# %%
gender_value_counts = gender_more50k.value_counts()
gender_value_counts
# Out:
# Male      9918
# Female    1769
# Name: gender, dtype: int64

# %%
gender_more50k.describe()
# Out:
# count     11687
# unique        2
# top        Male
# freq       9918
# Name: gender, dtype: object

# %%
plt.subplots(figsize = (5, 8))
sns.countplot(x = gender_more50k, data = df)
_ = plt.xlabel('Gender groups with income > 50k')

# %%
mix_more50k = people_more50k[['gender','race','relationship']]

# %%
mix_value_counts = mix_more50k.value_counts()
mix_value_counts
# Out:
# gender  race                relationship
# Male    White               Husband           8107
# Female  White               Wife               957
# Male    White               Not-in-family      741
# Female  White               Not-in-family      402
# Male    Black               Husband            376
#         Asian-Pac-Islander  Husband            300
#         White               Unmarried          133
# Female  White               Unmarried          129
#         Black               Wife                74
# Male    White               Own-child           61
#         Black               Not-in-family       47
# Female  Asian-Pac-Islander  Wife                44
#         White               Own-child           35
# Male    Other               Husband             32
#         Amer-Indian-Eskimo  Husband             31
# Female  Black               Not-in-family       30
# Male    Asian-Pac-Islander  Not-in-family       28
# Female  Black               Unmarried           25
# Male    White               Other-relative      22
# Female  White               Other-relative      19
#         Asian-Pac-Islander  Not-in-family       11
#         Amer-Indian-Eskimo  Wife                11
# Male    Black               Unmarried            9
# Female  Asian-Pac-Islander  Unmarried            7
# Male    Amer-Indian-Eskimo  Not-in-family        6
# Female  Other               Wife                 6
# Male    Asian-Pac-Islander  Own-child            5
# Female  Asian-Pac-Islander  Own-child            4
# Male    Other               Not-in-family        4
# Female  Other               Not-in-family        4
# Male    Asian-Pac-Islander  Other-relative       4
# Female  Amer-Indian-Eskimo  Not-in-family        3
# Male    Asian-Pac-Islander  Unmarried            3
# Female  Asian-Pac-Islander  Other-relative       3
# Male    Black               Own-child            2
# Female  Black               Own-child            2
# Male    Other               Own-child            1
#                             Unmarried            1
#         Amer-Indian-Eskimo  Other-relative       1
#         Other               Other-relative       1
#         Amer-Indian-Eskimo  Unmarried            1
#                             Own-child            1
# Female  Amer-Indian-Eskimo  Unmarried            1
#         Other               Other-relative       1
#         Black               Other-relative       1
# Male    White               Wife                 1
# dtype: int64

# %%
mix_more50k.describe()
# Out:
#        gender   race relationship
# count   11687  11687        11687
# unique      2      5            6
# top      Male  White      Husband
# freq     9918  10607         8846

# %% [markdown]
# ### Task 3

# %%
df['age'].max()
# Out:
# 90

# %%
df['age'].min()
# Out:
# 17

# %%
age_range = people_more50k['age'].apply(lambda x: '17-30' if x>=17 and x<=30 
                                         else '31-40' if x>=31 and x<=40 
                                         else '41-50' if x>=41 and x<=50 
                                         else '51-60' if x>=51 and x<=60
                                         else '61-70' if x>=61 and x<=70
                                         else '71-80' if x>=71 and x<=80
                                         else '81-90').value_counts()

# %%
age_range_more50k = age_range.idxmax()
age_range_more50k
# Out:
# '41-50'

# %% [markdown]
# ### Task 4

# %%
hour_week20 = df[df['hours-per-week'] <= 20]

# %%
hour_per_week20_more50 = len(hour_week20)/len(people_more50k)
hour_per_week20_more50
# Out:
# 0.38102164798494054

# %%
hour_week30 = df[df['hours-per-week'] <= 30]

# %%
hour_per_week30_more50 = len(hour_week30)/len(people_more50k)
hour_per_week30_more50
# Out:
# 0.6717720544194404

# %%
hour_week40 = df[df['hours-per-week'] <= 40]

# %%
hour_per_week40_more50 = len(hour_week40)/len(people_more50k)
hour_per_week40_more50
# Out:
# 2.951142294857534

# %% [markdown]
# ### Task 5

# %%
marital_status_more50k = people_more50k['marital-status']

# %%
marital_status_value_counts = marital_status_more50k.value_counts()
marital_status_value_counts
# Out:
# Married-civ-spouse       9984
# Never-married             733
# Divorced                  671
# Widowed                   128
# Separated                  99
# Married-spouse-absent      58
# Married-AF-spouse          14
# Name: marital-status, dtype: int64

# %%
occupation_more50k = people_more50k['occupation']

# %%
occupation_value_counts = occupation_more50k.value_counts()
occupation_value_counts
# Out:
# Exec-managerial      2908
# Prof-specialty       2784
# Sales                1475
# Craft-repair         1383
# Adm-clerical          768
# Transport-moving      481
# Tech-support          420
# Machine-op-inspct     372
# Protective-serv       308
# ?                     265
# Other-service         204
# Farming-fishing       173
# Handlers-cleaners     138
# Armed-Forces            5
# Priv-house-serv         3
# Name: occupation, dtype: int64

# %% [markdown]
# #### Считаю, что все задания были отлично составлены, поэтому все важные критерии были учтены в них:)))) лучше пОмОгИтЕ с 4 заданием, там какая-то дичь....

# %% [markdown]
# ### Task 6

# %% [markdown]
# #### Таким образом, если хотите стать богатым, то вам надо жить в США, быть женатым белым исполнительным директором в возрасте от 41 до 50,  и работать больше 50 часов в неделю :)))) хотя с последним вопросики....
